# %%
import pandas as pd

# %%
file_beneficiary_test = '/Users/keriwilkins/Downloads/Medicare-Fraud-Detection-DS/Test_Beneficiarydata-1542969243754.csv'

# %%
beneficiary_test_data = pd.read_csv(file_beneficiary_test)

# %%
print((beneficiary_test_data).shape)
# Out:
# (63968, 25)

# %%
print((beneficiary_test_data).dtypes)
# Out:
# BeneID                             object
# DOB                                object
# DOD                                object
# Gender                              int64
# Race                                int64
# RenalDiseaseIndicator              object
# State                               int64
# County                              int64
# NoOfMonths_PartACov                 int64
# NoOfMonths_PartBCov                 int64
# ChronicCond_Alzheimer               int64
# ChronicCond_Heartfailure            int64
# ChronicCond_KidneyDisease           int64
# ChronicCond_Cancer                  int64
# ChronicCond_ObstrPulmonary          int64
# ChronicCond_Depression              int64
# ChronicCond_Diabetes                int64
# ChronicCond_IschemicHeart           int64
# ChronicCond_Osteoporasis            int64
# ChronicCond_rheumatoidarthritis     int64
# ChronicCond_stroke                  int64
# IPAnnualReimbursementAmt            int64
# ...

# %%
print(beneficiary_test_data)
# Out:
#            BeneID         DOB         DOD  Gender  Race RenalDiseaseIndicator  \
# 0       BENE11001  1943-01-01         NaN       1     1                     0
# 1       BENE11007  1940-09-01  2009-12-01       1     2                     0
# 2       BENE11010  1936-07-01         NaN       2     1                     0
# 3       BENE11011  1914-03-01         NaN       2     2                     0
# 4       BENE11014  1938-04-01         NaN       2     1                     Y
# ...           ...         ...         ...     ...   ...                   ...
# 63963  BENE159187  1959-07-01         NaN       1     1                     0
# 63964  BENE159193  1936-12-01         NaN       2     1                     0
# 63965  BENE159194  1939-07-01         NaN       1     1                     0
# 63966  BENE159196  1916-06-01         NaN       2     1                     0
# 63967  BENE159197  1930-01-01         NaN       1     1                     0
#
# ...

# %%
file_inpatient_test = '/Users/keriwilkins/Downloads/Medicare-Fraud-Detection-DS/Test_Inpatientdata-1542969243754.csv'

# %%
inpatient_test_data = pd.read_csv(file_inpatient_test)

# %%
print((inpatient_test_data).shape)
# Out:
# (9551, 30)

# %%
print((inpatient_test_data).dtypes)
# Out:
# BeneID                     object
# ClaimID                    object
# ClaimStartDt               object
# ClaimEndDt                 object
# Provider                   object
# InscClaimAmtReimbursed      int64
# AttendingPhysician         object
# OperatingPhysician         object
# OtherPhysician             object
# AdmissionDt                object
# ClmAdmitDiagnosisCode      object
# DeductibleAmtPaid         float64
# DischargeDt                object
# DiagnosisGroupCode         object
# ClmDiagnosisCode_1         object
# ClmDiagnosisCode_2         object
# ClmDiagnosisCode_3         object
# ClmDiagnosisCode_4         object
# ClmDiagnosisCode_5         object
# ClmDiagnosisCode_6         object
# ClmDiagnosisCode_7         object
# ClmDiagnosisCode_8         object
# ClmDiagnosisCode_9         object
# ClmDiagnosisCode_10        object
# ClmProcedureCode_1        float64
# ClmProcedureCode_2        float64
# ClmProcedureCode_3        float64
# ...

# %%
print(inpatient_test_data)
# Out:
#           BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0      BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1      BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2      BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3      BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4      BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
# ...          ...       ...          ...         ...       ...
# 9546  BENE159139  CLM61015   2009-07-24  2009-07-26  PRV55021
# 9547  BENE159143  CLM42885   2009-03-16  2009-03-29  PRV55017
# 9548  BENE159155  CLM67124   2009-09-07  2009-10-12  PRV53758
# 9549  BENE159181  CLM72016   2009-10-14  2009-10-17  PRV57195
# 9550  BENE159196  CLM47313   2009-04-17  2009-04-18  PRV51854
#
#       InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       9000          PHY317786          PHY427017
# 1                      14000          PHY314656          PHY426644
# ...

# %%
file_outpatient_test = '/Users/keriwilkins/Downloads/Medicare-Fraud-Detection-DS/Test_Outpatientdata-1542969243754.csv'

# %%
outpatient_test_data = pd.read_csv(file_outpatient_test)

# %%
print((outpatient_test_data).shape)
# Out:
# (125841, 27)

# %%
print((outpatient_test_data).dtypes)
# Out:
# BeneID                     object
# ClaimID                    object
# ClaimStartDt               object
# ClaimEndDt                 object
# Provider                   object
# InscClaimAmtReimbursed      int64
# AttendingPhysician         object
# OperatingPhysician         object
# OtherPhysician             object
# ClmDiagnosisCode_1         object
# ClmDiagnosisCode_2         object
# ClmDiagnosisCode_3         object
# ClmDiagnosisCode_4         object
# ClmDiagnosisCode_5         object
# ClmDiagnosisCode_6         object
# ClmDiagnosisCode_7         object
# ClmDiagnosisCode_8         object
# ClmDiagnosisCode_9         object
# ClmDiagnosisCode_10        object
# ClmProcedureCode_1        float64
# ClmProcedureCode_2        float64
# ClmProcedureCode_3        float64
# ClmProcedureCode_4        float64
# ClmProcedureCode_5        float64
# ClmProcedureCode_6        float64
# DeductibleAmtPaid           int64
# ClmAdmitDiagnosisCode      object
# dtype: object

# %%
print(outpatient_test_data)
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1        BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2        BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3        BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4        BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
# ...            ...        ...          ...         ...       ...
# 125836  BENE159193  CLM469576   2009-07-14  2009-07-14  PRV55485
# 125837  BENE159193  CLM483842   2009-07-22  2009-07-22  PRV55485
# 125838  BENE159193  CLM554925   2009-08-31  2009-08-31  PRV55485
# 125839  BENE159194  CLM347777   2009-05-08  2009-05-08  PRV55889
# 125840  BENE159197  CLM357675   2009-05-13  2009-05-13  PRV52983
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                           30          PHY347633                NaN
# ...

# %%
file_test = '/Users/keriwilkins/Downloads/Medicare-Fraud-Detection-DS/Test-1542969243754.csv'

# %%
file_test_data = pd.read_csv(file_test)

# %%
print((file_test_data).shape)
# Out:
# (1353, 1)

# %%
print((file_test_data).dtypes)
# Out:
# Provider    object
# dtype: object

# %%
print(file_test_data)
# Out:
#       Provider
# 0     PRV51002
# 1     PRV51006
# 2     PRV51009
# 3     PRV51010
# 4     PRV51018
# ...        ...
# 1348  PRV57713
# 1349  PRV57726
# 1350  PRV57745
# 1351  PRV57749
# 1352  PRV57750
#
# [1353 rows x 1 columns]

# %%
file_beneficiary_train = '/Users/keriwilkins/Downloads/Medicare-Fraud-Detection-DS/Train_Beneficiarydata-1542865627584.csv'

# %%
beneficiary_train_data = pd.read_csv(file_beneficiary_train)

# %%
print((beneficiary_train_data).shape)
# Out:
# (138556, 25)

# %%
print((beneficiary_train_data).dtypes)
# Out:
# BeneID                             object
# DOB                                object
# DOD                                object
# Gender                              int64
# Race                                int64
# RenalDiseaseIndicator              object
# State                               int64
# County                              int64
# NoOfMonths_PartACov                 int64
# NoOfMonths_PartBCov                 int64
# ChronicCond_Alzheimer               int64
# ChronicCond_Heartfailure            int64
# ChronicCond_KidneyDisease           int64
# ChronicCond_Cancer                  int64
# ChronicCond_ObstrPulmonary          int64
# ChronicCond_Depression              int64
# ChronicCond_Diabetes                int64
# ChronicCond_IschemicHeart           int64
# ChronicCond_Osteoporasis            int64
# ChronicCond_rheumatoidarthritis     int64
# ChronicCond_stroke                  int64
# IPAnnualReimbursementAmt            int64
# ...

# %%
print(beneficiary_train_data)
# Out:
#             BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 0        BENE11001  1943-01-01  NaN       1     1                     0
# 1        BENE11002  1936-09-01  NaN       2     1                     0
# 2        BENE11003  1936-08-01  NaN       1     1                     0
# 3        BENE11004  1922-07-01  NaN       1     1                     0
# 4        BENE11005  1935-09-01  NaN       1     1                     0
# ...            ...         ...  ...     ...   ...                   ...
# 138551  BENE159194  1939-07-01  NaN       1     1                     0
# 138552  BENE159195  1938-12-01  NaN       2     1                     0
# 138553  BENE159196  1916-06-01  NaN       2     1                     0
# 138554  BENE159197  1930-01-01  NaN       1     1                     0
# 138555  BENE159198  1952-04-01  NaN       2     1                     0
#
#         State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# ...

# %%
file_inpatient_train = '/Users/keriwilkins/Downloads/Medicare-Fraud-Detection-DS/Train_Inpatientdata-1542865627584.csv'

# %%
inpatient_train_data = pd.read_csv(file_inpatient_train)

# %%
print((inpatient_train_data).shape)
# Out:
# (40474, 30)

# %%
print((inpatient_train_data).dtypes)
# Out:
# BeneID                     object
# ClaimID                    object
# ClaimStartDt               object
# ClaimEndDt                 object
# Provider                   object
# InscClaimAmtReimbursed      int64
# AttendingPhysician         object
# OperatingPhysician         object
# OtherPhysician             object
# AdmissionDt                object
# ClmAdmitDiagnosisCode      object
# DeductibleAmtPaid         float64
# DischargeDt                object
# DiagnosisGroupCode         object
# ClmDiagnosisCode_1         object
# ClmDiagnosisCode_2         object
# ClmDiagnosisCode_3         object
# ClmDiagnosisCode_4         object
# ClmDiagnosisCode_5         object
# ClmDiagnosisCode_6         object
# ClmDiagnosisCode_7         object
# ClmDiagnosisCode_8         object
# ClmDiagnosisCode_9         object
# ClmDiagnosisCode_10        object
# ClmProcedureCode_1        float64
# ClmProcedureCode_2        float64
# ClmProcedureCode_3        float64
# ...

# %%
print(inpatient_train_data)
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2       BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3       BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4       BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
# ...           ...       ...          ...         ...       ...
# 40469  BENE159167  CLM69886   2009-09-28  2009-10-02  PRV53671
# 40470  BENE159175  CLM74504   2009-11-03  2009-11-06  PRV54981
# 40471  BENE159177  CLM76485   2009-11-18  2009-11-22  PRV56588
# 40472  BENE159177  CLM79949   2009-12-17  2009-12-18  PRV56575
# 40473  BENE159188  CLM69948   2009-09-28  2009-10-06  PRV54765
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                        5000          PHY318495          PHY318495
# ...

# %%
file_outpatient_train = '/Users/keriwilkins/Downloads/Medicare-Fraud-Detection-DS/Train_Outpatientdata-1542865627584.csv'

# %%
outpatient_train_data = pd.read_csv(file_outpatient_train)

# %%
print((outpatient_train_data).shape)
# Out:
# (517737, 27)

# %%
print((outpatient_train_data).dtypes)
# Out:
# BeneID                     object
# ClaimID                    object
# ClaimStartDt               object
# ClaimEndDt                 object
# Provider                   object
# InscClaimAmtReimbursed      int64
# AttendingPhysician         object
# OperatingPhysician         object
# OtherPhysician             object
# ClmDiagnosisCode_1         object
# ClmDiagnosisCode_2         object
# ClmDiagnosisCode_3         object
# ClmDiagnosisCode_4         object
# ClmDiagnosisCode_5         object
# ClmDiagnosisCode_6         object
# ClmDiagnosisCode_7         object
# ClmDiagnosisCode_8         object
# ClmDiagnosisCode_9         object
# ClmDiagnosisCode_10        object
# ClmProcedureCode_1        float64
# ClmProcedureCode_2        float64
# ClmProcedureCode_3        float64
# ClmProcedureCode_4        float64
# ClmProcedureCode_5        float64
# ClmProcedureCode_6        float64
# DeductibleAmtPaid           int64
# ClmAdmitDiagnosisCode      object
# dtype: object

# %%
print(outpatient_train_data)
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1        BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2        BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3        BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4        BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
# ...            ...        ...          ...         ...       ...
# 517732  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 517733  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 517734  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 517735  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 517736  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                           30          PHY326117                NaN
# ...

# %%
file_train = '/Users/keriwilkins/Downloads/Medicare-Fraud-Detection-DS/Train-1542865627584.csv'

# %%
train_data = pd.read_csv(file_train)

# %%
print((train_data).shape)
# Out:
# (5410, 2)

# %%
print((train_data).dtypes)
# Out:
# Provider          object
# PotentialFraud    object
# dtype: object

# %%
print(train_data)
# Out:
#       Provider PotentialFraud
# 0     PRV51001             No
# 1     PRV51003            Yes
# 2     PRV51004             No
# 3     PRV51005            Yes
# 4     PRV51007             No
# ...        ...            ...
# 5405  PRV57759             No
# 5406  PRV57760             No
# 5407  PRV57761             No
# 5408  PRV57762             No
# 5409  PRV57763             No
#
# [5410 rows x 2 columns]

# %%
http://localhost:8888/notebooks/Provider%20Fraud%20in%20Medicare%20Claims%20Study%20.ipynb
